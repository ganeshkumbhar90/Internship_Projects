# %%
# Importing Libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# Activating the chrome browser 
driver = webdriver.Chrome(r"C:\WebDriver\chromedriver_win32\chromedriver.exe")

# %% [raw]
# # Opening the homepage
# driver=webdriver.Chrome()
# driver.get('https://www.google.com/')

# %% [markdown]
# ### Question 1
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
rank = driver.find_elements_by_xpath("//div[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[1]")
Rank=[]
for i in rank:
    if i.text is None:
        Rank.append("-")
    else:
        Rank.append(i.text.replace(".",""))

# %%
name = driver.find_elements_by_xpath("//div[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[2]")
Name=[]
for i in name:
    if i.text is None:
        Name.append("-")
    else:
        Name.append(i.text.replace('"',""))

# %%
uploader = driver.find_elements_by_xpath("//div[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[3]")
Artist=[]
for i in uploader:
    if i.text is None:
        Arist.append("-")
    else:
        Artist.append(i.text)

# %%
views = driver.find_elements_by_xpath("//div[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[4]")
Views=[]
for i in views:
    if i.text is None:
        Views.append("-")
    else:
        Views.append(i.text)

# %%
date = driver.find_elements_by_xpath("//div[@id='mw-content-text']/div[1]/table[3]/tbody/tr/td[5]")
Upload_date=[]
for i in date:
    if i.text is None:
        Upload_date.append("-")
    else:
        Upload_date.append(i.text)

# %%
df=pd.DataFrame({})
df['Rank']=Rank
df['Video_name']=Name
df['Artist']=Artist
df['Upload_date']=Upload_date
df['Views']=Views
df
# Out:
#    Rank                                     Video_name  \
# 0     1                           Baby Shark Dance[23]
# 1     2                                  Despacito[25]
# 2     3                       Johny Johny Yes Papa[26]
# 3     4                               Shape of You[27]
# 4     5                              See You Again[28]
# 5     6                                  Bath Song[31]
# 6     7  Learning Colors – Colorful Eggs on a Farm[32]
# 7     8   Masha and the Bear – Recipe for Disaster[33]
# 8     9                                Uptown Funk[34]
# 9    10                Phonics Song with Two Words[35]
# 10   11                              Gangnam Style[36]
# 11   12                             Dame Tu Cosita[38]
# 12   13                                      Sugar[39]
# 13   14                                      Sorry[40]
# 14   15                                       Roar[41]
# 15   16                             Counting Stars[42]
# ...

# %% [markdown]
# ### Question 2
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Activating the chrome browser 
driver = webdriver.Chrome(r"C:\WebDriver\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.bcci.tv/"
driver.get(url)

# %%
time.sleep(3)

# %%
drop_down = driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']").click()

# %%
time.sleep(3)

# %%
drop_down = driver.find_element_by_xpath("//a[@class='navigation__link navigation__link--in-drop-down']").click()

# %%
match_title = driver.find_elements_by_xpath("//strong[@class='fixture__name fixture__name--with-margin']")
Match_title=[]
for i in match_title:
    if i.text is None:
        Match_title.append("-")
    else:
        Match_title.append(i.text)

# %%
series = driver.find_elements_by_xpath("//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
Series=[]
for i in series:
    if i.text is None:
        Series.append("-")
    else:
        Series.append(i.text)

# %%
place = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
Place=[]
for i in place:
    if i.text is None:
        Place.append("-")
    else:
        Place.append(i.text)

# %%
date = driver.find_elements_by_xpath("//span[@class='fixture__date']")
Date=[]
for i in date:
    if i.text is None:
        Date.append("-")
    else:
        Date.append(i.text)

# %%
month = driver.find_elements_by_xpath("//span[@class='fixture__month']")
Month=[]
for i in month:
    if i.text is None:
        Month.append("-")
    else:
        Month.append(i.text)

# %%
time = driver.find_elements_by_xpath("//span[@class='fixture__time']")
Time=[]
for i in time:
    if i.text is None:
        Time.append("-")
    else:
        Time.append(i.text)

# %%
df=pd.DataFrame({})
df['Match_title']=Match_title[:12]
df['Series']=Series[:12]
df['Place']=Place[:12]
df['Full_date']=Date[:12]
df['Time']=time[:12]
df['Month']=Month[:12]
df
# Out:
#    Match_title                          Series  \
# 0     1st Test        INDIA V NEW ZEALAND 2021
# 1     2nd Test        INDIA V NEW ZEALAND 2021
# 2     1st Test  SOUTH AFRICA V INDIA 2021/2022
# 3     2nd Test  SOUTH AFRICA V INDIA 2021/2022
# 4     3rd Test  SOUTH AFRICA V INDIA 2021/2022
# 5      1st ODI  SOUTH AFRICA V INDIA 2021/2022
# 6      2nd ODI  SOUTH AFRICA V INDIA 2021/2022
# 7      3rd ODI  SOUTH AFRICA V INDIA 2021/2022
# 8     1st T20I  SOUTH AFRICA V INDIA 2021/2022
# 9     2nd T20I  SOUTH AFRICA V INDIA 2021/2022
# 10    3rd T20I  SOUTH AFRICA V INDIA 2021/2022
# 11    4th T20I  SOUTH AFRICA V INDIA 2021/2022
#
#                                   Place Full_date  \
# 0                    Green Park, Kanpur        25
# 1              Wankhede Stadium, Mumbai        03
# 2   New Wanderers Stadium, Johannesburg        17
# 3            Supersport Park, Centurion        26
# 4                   Newlands, Cape Town        03
# ...

# %% [markdown]
# ### Question 3
# Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
# Activating the chrome browser 
driver = webdriver.Chrome(r"C:\WebDriver\chromedriver_win32\chromedriver.exe")

# %%
url = "https://www.guru99.com/"
driver.get(url)

# %%
Button= driver.find_element_by_xpath("//button[@class='gsc-search-button gsc-search-button-v2']").click()
search=driver.find_element_by_xpath("//input[@class='gsc-input']")
search.send_keys('selenium exception handling')

# %%
name =driver.find_elements_by_xpath("//div[@class='gs-title']")
Name=[]
for i in name:
    if i.text is None:
        Name.append("-")
    else:
        Name.append(i.text)

# %%
desc =driver.find_elements_by_xpath("//div[@class='gs-title']")
description=[]
for i in desc:
    if i.text is None:
        description.append("-")
    else:
        description.append(i.text)

# %%
df = pd.DataFrame({})
df['Name'] = Name
df['description'] = description

# %%
df[:10]
# Out:
#                                                 Name  \
# 0  Selenium Exception Handling (Common Exceptions...
# 1  How to Handle SSL Certificate in Selenium WebD...
# 2      Try Catch in Java: Exception Handling Example
# 3  Selenium Alert & Popup Window Handling: How to...
# 4  Python Exception Handling: try, catch, finally...
# 5  Top 100 Selenium Interview Questions and Answe...
# 6  VB.Net Exception Handling | Try, Catch, Error ...
# 7  PHP Try Catch Example: Exception & Error Handl...
# 8  Oracle PL/SQL Exception Handling: Examples to ...
# 9  JSP Exception Handling | Error Handling in JSP...
#
#                                          description
# 0  Selenium Exception Handling (Common Exceptions...
# 1  How to Handle SSL Certificate in Selenium WebD...
# 2      Try Catch in Java: Exception Handling Example
# 3  Selenium Alert & Popup Window Handling: How to...
# 4  Python Exception Handling: try, catch, finally...
# 5  Top 100 Selenium Interview Questions and Answe...
# ...

# %% [markdown]
# ### Question 4
# Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
url = "http://statisticstimes.com/"
driver.get(url)

# %%
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="top"]/div[2]/div[2]/button'))).click()
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="top"]/div[2]/div[2]/div/a[3]'))).click()
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[2]/div[2]/div[2]/ul/li[1]/a'))).click()

# %%
Rank=[]
rank = driver.find_elements_by_xpath("//td[@class='data1']")[0:33]
for i in rank:
    if i.text is None:
        Rank.append("-")
    else:
        Rank.append(i.text)

# %%
State=[]
state = driver.find_elements_by_xpath("//td[@class='name']")[0:33]
for i in state:
    if i.text is None:
        State.append("-")
    else:
        State.append(i.text)

# %%
GSDP_19_to_20=[]
gsdp = driver.find_elements_by_xpath("//td[3][@class='data']")[0:33]
for i in gsdp:
    if i.text is None:
        GSDP_19_to_20.append("-")
    else:
        GSDP_19_to_20.append(i.text)

# %%
GSDP_18_to_19=[]
gsdp = driver.find_elements_by_xpath("//td[@class='data sorting_1']")[0:33]
for i in gsdp:
    if i.text is None:
        GSDP_18_to_19.append("-")
    else:
        GSDP_18_to_19.append(i.text)

# %%
SHARE=[]
share = driver.find_elements_by_xpath("//td[5][@class='data']")[0:33]
for i in share:
    if i.text is None:
        SHARE.append("-")
    else:
        SHARE.append(i.text)

# %%
GDP_dollar=[]
gdp = driver.find_elements_by_xpath("//td[6][@class='data']")[0:33]
for i in gdp:
    if i.text is None:
        GDP_dollar.append("-")
    else:
        GDP_dollar.append(i.text)

# %%
df=pd.DataFrame({})
df['RANK']=Rank
df['STATE']=State
df['GSDP 19-20']=GSDP_19_to_20
df['GSDP 18-19']=GSDP_18_to_19
df['SHARE']=SHARE
df['GDP_BILLION $']=GDP_dollar
df
# Out:
#    RANK                      STATE GSDP 19-20 GSDP 18-19   SHARE GDP_BILLION $
# 0     1                Maharashtra          -  2,632,792  13.94%       399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%       247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%       240.726
# 3     4                    Gujarat          -  1,502,899   7.96%       228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%       226.806
# 5     6                West Bengal  1,253,832  1,089,898   5.77%       165.556
# 6     7                  Rajasthan  1,020,989    942,586   4.99%       143.179
# 7     8             Andhra Pradesh    972,782    862,957   4.57%       131.083
# 8     9                  Telangana    969,604    861,031   4.56%       130.791
# 9    10             Madhya Pradesh    906,672    809,592   4.29%       122.977
# 10   11                     Kerala          -    781,653   4.14%       118.733
# ...

# %% [markdown]
# ### Question 5
# Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# Activating the chrome browser 
driver = webdriver.Chrome(r"C:\WebDriver\chromedriver_win32\chromedriver.exe")

# %%
url = "https://github.com/explore"
driver.get(url)

# %%
/html/body/div[4]/main/div[1]/nav/div/a[3]

# %%
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[4]/main/div[1]/nav/div/a[3]'))).click()

# %%
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary'))).click()
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a'))).click()

# %%
urls=[]
for i in driver.find_elements_by_xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article/h1/a'):
    urls.append(i.get_attribute("href"))

# %%
Title=[]
Description=[]
contributer_count=[]
Language_used=[]

# %%
for i in urls:
    driver.get(i)
    try:
        title=driver.find_element_by_xpath('//h1[@class=" d-flex flex-wrap flex-items-center break-word f3 text-normal"]')
        Title.append(title.text.replace('\n',' '))
    except NoSuchElementException:
        Title.append('-')
        
    try:
        description=driver.find_element_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[1]/div/p')
        Description.append(description.text)
    except NoSuchElementException:
        Description.append('-')
        
    try:
        count=driver.find_element_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[5]/div/h2/a/span')
        contributer_count.append(count.text)
    except NoSuchElementException:
        contributer_count.append('-')

    try:
        lang=driver.find_element_by_xpath('//*[@id="repo-content-pjax-container"]/div/div[2]/div[2]/div/div[6]/div/ul/li/a/span[1]')
        Language_used.append(lang.text.replace('\n',' '))
    except NoSuchElementException:
        Language_used.append('-')

# %%
df=pd.DataFrame({})
df['Repository_Title']=Title
df['Repository_Description']=Description
df['Contributer_Count']=contributer_count
df['Language_Used']=Language_used
df
# Out:
#    Repository_Title                             Repository_Description  \
# 0                 -                                                  -
# 1                 -                               收集免费的接口服务,做一个api的搬运工
# 2                 -          Wazuh - The Open Source Security Platform
# 3                 -          Becoming better at data science every day
# 4                 -  A quicker and better cross-platform SSH/Sftp/S...
# 5                 -  Object detection and instance segmentation too...
# 6                 -                                  零反射全动态Android插件框架
# 7                 -  分享 GitHub 上有趣、入门级的开源项目。Share interesting, entr...
# 8                 -  Robust Video Matting in PyTorch, TensorFlow, T...
# 9                 -  [Open Source]. The improved version of AnimeGA...
# 10                -                       📚 µGo语言实现(如何从头开发一个迷你Go语言编译器)
# 11                -  A chrome extension for automating your browser...
# ...

# %% [markdown]
# ### Question 6

# %% [raw]
# Question 6
# 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Activating the chrome browser 
driver = webdriver.Chrome(r"C:/WebDriver/chromedriver_win32/chromedriver.exe")

# %%
url = "https://www.billboard.com/"
driver.get(url)

# %%
search = driver.find_element_by_xpath("/html/body/div[4]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a").click()
search = driver.find_element_by_xpath("/html/body/div[4]/header/div[2]/div/nav/ul/li[1]/a").click()

# %%
#search=driver.find_element_by_xpath('/html/body/div[4]/header/div[2]/div/nav/ul/li[1]/a')

# %%
Song=[]
song = driver.find_elements_by_xpath("//h3[@class='ing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
for i in song:
    if i.text is None:
        Song.append("-")
    else:
        Song.append(i.text)

# %%
Song=[]
song = driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
for i in song:
    if i.text is None:
        Song.append("-")
    else:
        Song.append(i.text)

# %%
len(Song)
# Out:
# 99

# %%
Artist=[]
artist = driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']")
for i in artist:
    if i.text is None:
        Artist.append("-")
    else:
        Artist.append(i.text)

# %%
Artist=[]
artist = driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in artist:
    if i.text is None:
        Artist.append("-")
    else:
        Artist.append(i.text)

# %%
len(Artist)
# Out:
# 99

# %%
This_week_rank=[]
lastw_rank = driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // lrv-u-background-color-black lrv-u-color-white u-width-100 u-width-55@mobile-max u-width-55@tablet-only lrv-u-height-100p lrv-u-flex lrv-u-flex-direction-column@mobile-max lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey']")
for i in lastw_rank:
    if i.text is None:
        last_week_rank.append("-")
    else:
        last_week_rank.append(i.text)

# %%
new_list = []

for i in driver.find_elements_by_xpath('//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]'):
    if i.text is None:
        new_list.append('')
    else:
        new_list.append(i.text)

# %%
last_week_rank = []
peak_rank = []
weeks_on_chart = []
for i in range(0,len(new_list)-1,6):
    last_week_rank.append(new_list[i])
    peak_rank.append(new_list[i+1])
    weeks_on_chart.append(new_list[i+2])

# %%
print(len(last_week_rank),len(weeks_on_chart),len(peak_rank),)
# Out:
# 99 99 99

# %% [markdown]
# last_week_rank=[]
# lastw_rank = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
# for i in lastw_rank:
#     if i.text is None:
#         last_week_rank.append("-")
#     else:
#         last_week_rank.append(i.text)

# %%
df=pd.DataFrame({})
df['SONG NAME']=Song
df['ARTIST NAME']=Artist
df['LAST WEEK RANK']=last_week_rank
df['PEAK RANK']=peak_rank
df['WEEKS ON BOARD']=weeks_on_chart
df
# Out:
#                 SONG NAME                               ARTIST NAME  \
# 0              Easy On Me                                     Adele
# 1                    Stay             The Kid LAROI & Justin Bieber
# 2           Industry Baby                   Lil Nas X & Jack Harlow
# 3   Smokin Out The Window  Silk Sonic (Bruno Mars & Anderson .Paak)
# 4              Bad Habits                                Ed Sheeran
# ..                    ...                                       ...
# 94        Moth To A Flame          Swedish House Mafia & The Weeknd
# 95         'Til You Can't                              Cody Johnson
# 96                  Woman                                  Doja Cat
# 97         Take My Breath                                The Weeknd
# 98            For Tonight                                    Giveon
#
#    LAST WEEK RANK PEAK RANK WEEKS ON BOARD
# 0               1         1              6
# 1               2         1             19
# ...

# %% [markdown]
# # Question 7

# %% [raw]
# Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
url = "https://www.naukri.com/"
driver.get(url)

# %%
job_search = driver.find_element_by_id('qsb-keyword-sugg')
job_search.send_keys('Data Scientist')

# %%
search_btn = driver.find_element_by_xpath("//button[@class = 'btn']")
search_btn.click()

# %%
Name=[]
name = driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in name:
    if i.text is None:
        Name.append("-")
    else:
        Name.append(i.text)

# %%
Company=[]
comp = driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
for i in comp:
    if i.text is None:
        Company.append("-")
    else:
        Company.append(i.text)

# %%
Skills=[]
skills = driver.find_elements_by_xpath("//ul[@class='tags has-description']")
for i in skills:
    if i.text is None:
        Skills.append("-")
    else:
        Skills.append(i.text)

# %%
Location=[]
url=[]
urls=driver.find_elements_by_xpath("a[@class='subTitle ellipsis fleft']")
for i in urls:
    url.append(i.get_attribute("href"))
    
for i in url:
    driver.get(i)
    try:
        location=driver.find_element_by_xpath("span[@class='location]")
        Location.append(location.text)
    except NoSuchElementException:
        Location.append('-')

# %%
location = driver.find_elements_by_xpath("//li[@class = 'fleft grey-text br2 placeHolderLi location']")
Location = []
for i in location:
    Location.append(i.text)

# %%
df=pd.DataFrame({})
df['NAME']=Name
df['SKILL']=Skills
df['LOCATION']=Location
df['COMPANY']=Company
df
# Out:
#                                                  NAME  \
# 0                                      Data Scientist
# 1             Data Scientist: Artificial Intelligence
# 2                               Senior Data Scientist
# 3                           IDM - Lead Data Scientist
# 4                                 Lead Data Scientist
# 5        Senior Data Scientist - Statistical Modeling
# 6                       Associate Data Scientist I/II
# 7        Senior Data Scientist - Statistical Modeling
# 8            Senior Data Scientist - SQL/Python/Numpy
# 9                  Senior Specialist - Data Scientist
# 10  Data Analyst / Data Scientist / Business Analy...
# 11       Business Analysis/ Data Scientist/ Python/R/
# 12       Business Analysis/ Data Scientist/ Python/R/
# 13                              Senior Data Scientist
# 14              Data Scientist/ Senior Data Scientist
# 15                Senior Data Scientist (Theoretical)
# ...

# %% [markdown]
# ### Question 8

# %% [raw]
# Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/"
url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/'
driver.get(url)

# %% [raw]
# Name=[]
# name = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/a")
# for i in name:
#     if i.text is None:
#         Name.append("-")
#     else:
#         Name.append(i.text)

# %%
new_list = []

for i in driver.find_elements_by_xpath('//td[@class="left"]'):
    if i.text is None:
        new_list.append('')
    else:
        new_list.append(i.text)

# %%
rank_no=[]
book_name = []
author_name = []
volumes_sold = []
publisher=[]
genre=[]

for i in range(0,len(new_list)-1,5):
    rank_no.append(new_list[i])
    book_name.append(new_list[i+1])
    author_name.append(new_list[i+2])
    volumes_sold.append(new_list[i+3])
    publisher.append(new_list[i+4])
    #genre.append(new_list[i+4])

# %%
genres = driver.find_elements_by_xpath("//td[@class ='last left']")

for i in genres:
    genre.append(i.text)

# %%
print(len(rank_no),len(book_name),len(author_name),len(volumes_sold),len(publisher),len(genre))
# Out:
# 100 100 100 100 100 100

# %%
Best_Selling_Book=pd.DataFrame({})
Best_Selling_Book['Rank No']=rank_no
Best_Selling_Book['BOOK NAME']=book_name
Best_Selling_Book['Authors Name']=author_name
Best_Selling_Book['Volumes Sold']=volumes_sold
Best_Selling_Book['Publisher']=publisher
Best_Selling_Book['Genre']=genre
Best_Selling_Book
# Out:
#    Rank No                                          BOOK NAME  \
# 0        1                                  Da Vinci Code,The
# 1        2               Harry Potter and the Deathly Hallows
# 2        3           Harry Potter and the Philosopher's Stone
# 3        4          Harry Potter and the Order of the Phoenix
# 4        5                               Fifty Shades of Grey
# ..     ...                                                ...
# 95      96                                          Ghost,The
# 96      97                     Happy Days with the Naked Chef
# 97      98              Hunger Games,The:Hunger Games Trilogy
# 98      99  Lost Boy,The:A Foster Child's Search for the L...
# 99     100  Jamie's Ministry of Food:Anyone Can Learn to C...
#
#         Authors Name Volumes Sold        Publisher  \
# 0         Brown, Dan    5,094,805       Transworld
# 1      Rowling, J.K.    4,475,152       Bloomsbury
# 2      Rowling, J.K.    4,200,654       Bloomsbury
# ...

# %% [markdown]
# ### Question 9

# %% [raw]
# Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
Name=[]
name = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/a")
for i in name:
    if i.text is None:
        Name.append("-")
    else:
        Name.append(i.text)

# %%
Year_span=[]
year = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/span[2]")
for i in year:
    if i.text is None:
        Year_span.append("-")
    else:
        Year_span.append(i.text)

# %%
TV_genre=[]
tvgenre = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[1]/span[5]")
for i in tvgenre:
    if i.text is None:
        TV_genre.append("-")
    else:
        TV_genre.append(i.text)

# %%
Runtime=[]
runtime = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[1]/span[3]")
for i in runtime:
    if i.text is None:
        Runtime.append("-")
    else:
        Runtime.append(i.text)

# %%
Rating=[]
rating = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/div[1]/div[1]/span[2]")
for i in rating:
    if i.text is None:
        Rating.append("-")
    else:
        Rating.append(i.text)

# %%
Votes=[]
votes = driver.find_elements_by_xpath("/html/body/div[4]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[4]/span[2]")
for i in votes:
    if i.text is None:
        Votes.append("-")
    else:
        Votes.append(i.text)

# %%
df=pd.DataFrame({})
df['TV_SHOW_NAME']=Name
df['YEAR_SPAN']=Year_span
df['TV_GENRE']=TV_genre
df['RUNTIME']=Runtime
df['RATING']=Rating
df['VOTES']=Votes
df
# Out:
#                       TV_SHOW_NAME    YEAR_SPAN                  TV_GENRE  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     RUNTIME RATING      VOTES
# 0    57 min    9.2  1,904,989
# ...

# %% [markdown]
# ### Question 10

# %% [raw]
# Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
# Importing Libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# Activating the chrome browser 
driver = webdriver.Chrome(r"C:/WebDriver/chromedriver_win32/chromedriver.exe")

# %%
url = "https://archive.ics.uci.edu/"
driver.get(url)

# %%
search = driver.find_element_by_xpath("/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b").click()

# %%
Name=[]
name = driver.find_elements_by_xpath("//p[@class='normal']/b/a")
for i in name:
    if i.text is None:
        Name.append("-")
    else:
        Name.append(i.text)

# %%
data_types=[]
data_type = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
for i in data_type:
    if i.text is None:
        data_types.append("-")
    else:
        data_types.append(i.text)

# %%
task=[]
tasks= driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
for i in tasks:
    if i.text is None:
        task.append("-")
    else:
        task.append(i.text)

# %%
attribute=[]
attri= driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p")
for i in attri:
    if i.text is None:
        attribute.append("-")
    else:
        attribute.append(i.text)

# %%
no_of_instances=[]
instances= driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p")
for i in instances:
    if i.text is None:
        no_of_instances.append("-")
    else:
        no_of_instances.append(i.text)

# %%
no_of_attribute=[]
attribute = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")
for i in attribute:
    if i.text is None:
        no_of_attribute.append("-")
    else:
        no_of_attribute.append(i.text)

# %%
year=[]
years = driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")
for i in years:
    if i.text is None:
        year.append("-")
    else:
        year.append(i.text)

# %%
print(len(name),len(data_types),len(task),len(attribute),len(no_of_instances),len(no_of_attribute),len(year))
# Out:
# 588 589 589 589 589 589 589

# %%
UCI_Machine_Learning_Repositories=pd.DataFrame({})
UCI_Machine_Learning_Repositories['Dataset Name']=Name
UCI_Machine_Learning_Repositories['Data Types']=data_types[1:589]
UCI_Machine_Learning_Repositories['Deafult Task']=task[1:589]
UCI_Machine_Learning_Repositories['Attribute Type']=attribute[1:589]
UCI_Machine_Learning_Repositories['No_of_instances']=no_of_instances[1:589]
UCI_Machine_Learning_Repositories['No_of_attribute']=no_of_attribute[1:589]
UCI_Machine_Learning_Repositories['Year']=year[1:589]
UCI_Machine_Learning_Repositories
# Out:
#                          Dataset Name     Data Types          Deafult Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute Type No_of_instances No_of_attribute   Year
# ...
